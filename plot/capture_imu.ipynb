# %%
pip install pyserial pandas matplotlib
# Out:
# Collecting pyserial
#   Using cached pyserial-3.5-py2.py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: pandas in c:\users\dipes\onedrive\documents\machine learning\python\test_project\.conda\lib\site-packages (2.3.0)
# Requirement already satisfied: matplotlib in c:\users\dipes\onedrive\documents\machine learning\python\test_project\.conda\lib\site-packages (3.10.3)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\dipes\onedrive\documents\machine learning\python\test_project\.conda\lib\site-packages (from pandas) (2.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dipes\onedrive\documents\machine learning\python\test_project\.conda\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dipes\onedrive\documents\machine learning\python\test_project\.conda\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dipes\onedrive\documents\machine learning\python\test_project\.conda\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dipes\onedrive\documents\machine learning\python\test_project\.conda\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\dipes\onedrive\documents\machine learning\python\test_project\.conda\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dipes\onedrive\documents\machine learning\python\test_project\.conda\lib\site-packages (from matplotlib) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dipes\onedrive\documents\machine learning\python\test_project\.conda\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\dipes\onedrive\documents\machine learning\python\test_project\.conda\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\dipes\onedrive\documents\machine learning\python\test_project\.conda\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dipes\onedrive\documents\machine learning\python\test_project\.conda\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: six>=1.5 in c:\users\dipes\onedrive\documents\machine learning\python\test_project\.conda\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached pyserial-3.5-py2.py3-none-any.whl (90 kB)
# Installing collected packages: pyserial
# Successfully installed pyserial-3.5
# Note: you may need to restart the kernel to use updated packages.

# %%
import time
import csv
import serial

# %%
# --------- CONFIG ----------
PORT = "COM20"  # Windows example: "COM5"
# PORT = "/dev/ttyUSB0"  # Linux example
# PORT = "/dev/tty.usbserial-XXXX"  # macOS example
BAUD = 115200

DURATION_SEC = 20  # capture length
OUT_CSV = "dual_mpu_capture.csv"

# Expected columns from your firmware:
# SEQ,T_US,A1X,A1Y,A1Z,G1X,G1Y,G1Z,A2X,A2Y,A2Z,G2X,G2Y,G2Z
EXPECTED_COLS = 14


def main():
    ser = serial.Serial(PORT, BAUD, timeout=1)
    print(f"Connected to {PORT} @ {BAUD}")

    # Give board time to reset + print header
    time.sleep(2.0)
    ser.reset_input_buffer()

    rows = 0
    bad_lines = 0
    last_seq = None
    drops = 0

    t0 = time.time()

    with open(OUT_CSV, "w", newline="") as f:
        w = csv.writer(f)
        w.writerow(
            [
                "SEQ",
                "T_US",
                "A1X",
                "A1Y",
                "A1Z",
                "G1X",
                "G1Y",
                "G1Z",
                "A2X",
                "A2Y",
                "A2Z",
                "G2X",
                "G2Y",
                "G2Z",
            ]
        )

        while time.time() - t0 < DURATION_SEC:
            line = ser.readline().decode(errors="ignore").strip()
            if not line:
                continue

            # Skip header line if it appears
            if line.startswith("SEQ") or "A1X" in line:
                continue

            parts = line.split(",")
            if len(parts) != EXPECTED_COLS:
                bad_lines += 1
                continue

            try:
                seq = int(parts[0])
                # quick drop detection
                if last_seq is not None and seq != last_seq + 1:
                    drops += (seq - last_seq - 1) if seq > last_seq else 0
                last_seq = seq

                # Write as-is (string -> CSV). Plot script will parse numeric.
                w.writerow(parts)
                rows += 1

            except ValueError:
                bad_lines += 1
                continue

    ser.close()

    elapsed = time.time() - t0
    hz = rows / elapsed if elapsed > 0 else 0

    print("\n--- Capture Summary ---")
    print(f"Saved: {OUT_CSV}")
    print(f"Duration: {elapsed:.2f}s")
    print(f"Valid rows: {rows}")
    print(f"Bad lines: {bad_lines}")
    print(f"Estimated rate: {hz:.1f} Hz")
    print(f"Detected seq drops: {drops}")


if __name__ == "__main__":
    main()
# Out:
# Connected to COM20 @ 115200
#
# --- Capture Summary ---
# Saved: dual_mpu_capture.csv
# Duration: 20.00s
# Valid rows: 2000
# Bad lines: 1
# Estimated rate: 100.0 Hz
# Detected seq drops: 0
